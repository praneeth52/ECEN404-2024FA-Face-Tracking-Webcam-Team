# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Sat Nov 23 19:07:53 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0              48W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# ...

# %%
# %cd drive/MyDrive/YOLO
# Out:
# /content/drive/MyDrive/YOLO

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.3/887.3 kB 49.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !pwd
# Out:
# /content/drive/MyDrive/YOLO

# %%
# !ls
# Out:
# dataset      faceDetectionYOLOv8.yaml  YOLO.ipynb  YOLOv5n.ipynb
# dataset.zip  testImages		       yolov5	   YOLOv9.ipynb

# %%
# !watch -n 1 nvidia-smi
# Out:
# >

# %%
model = YOLO('yolov8s.pt')
model.train(data='/content/drive/MyDrive/YOLO/faceDetectionYOLOv8.yaml', epochs=250, batch=64, imgsz=640, project='/content/drive/MyDrive/YOLO/YOLOv8sTraining', name='facialDetection', device=0, lr0=0.04)
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 177MB/s]
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
# !pwd
# Out:
# /content/drive/MyDrive/YOLO/dataset/images/train

# %%
# !unzip -j /content/drive/MyDrive/YOLO/dataset/images/train/train.zip -d /content/drive/MyDrive/YOLO/dataset/images/train
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/train/3c929afd5500ac99.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/train/._3c929afd5500ac99.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/train/209d946dd3c849e8.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/train/._209d946dd3c849e8.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/train/690ede1305990614.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/train/._690ede1305990614.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/train/870b5a1ceb2070bb.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/train/._870b5a1ceb2070bb.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/train/e64a00d409d5905a.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/train/._e64a00d409d5905a.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/train/615d9c2898c2d13a.jpg
# ...

# %%
# !ls -1 /content/drive/MyDrive/YOLO/dataset/images/train | wc -l
# Out:
# 26266

# %%
# !unzip -j /content/drive/MyDrive/YOLO/dataset/images/val/val.zip -d /content/drive/MyDrive/YOLO/dataset/images/val
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/val/5e505ca46e4f358b.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/val/._5e505ca46e4f358b.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/val/c5583249f107aa9e.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/val/._c5583249f107aa9e.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/val/0084d707a9cca12b.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/val/._0084d707a9cca12b.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/val/ca45ae6fc89c0f9f.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/val/._ca45ae6fc89c0f9f.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/val/f807e10d7d287476.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/val/._f807e10d7d287476.jpg
#   inflating: /content/drive/MyDrive/YOLO/dataset/images/val/6a5574c4ef0ba3b3.jpg
# ...

# %%
# !unzip -j /content/drive/MyDrive/YOLO/dataset/labels/val/val.zip -d /content/drive/MyDrive/YOLO/dataset/labels/val
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/val/6613af82809debe4.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/val/._6613af82809debe4.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/val/416c6055f4e7535a.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/val/._416c6055f4e7535a.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/val/020517b9eff94e00.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/val/._020517b9eff94e00.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/val/98d18acc964e7474.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/val/._98d18acc964e7474.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/val/0873e0bfa9309e2f.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/val/._0873e0bfa9309e2f.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/val/54ee1150204be163.txt
# ...

# %%
# !unzip -j /content/drive/MyDrive/YOLO/dataset/labels/train/train.zip -d /content/drive/MyDrive/YOLO/dataset/labels/train
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/train/4e9ffbde85b77d44.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/train/._4e9ffbde85b77d44.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/train/ac625d48a0281d44.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/train/._ac625d48a0281d44.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/train/1c6e1606b854bec2.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/train/._1c6e1606b854bec2.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/train/c07a9a8ddd6a36fb.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/train/._c07a9a8ddd6a36fb.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/train/77197324535ce923.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/train/._77197324535ce923.txt
#   inflating: /content/drive/MyDrive/YOLO/dataset/labels/train/038adeb1efe12cb0.txt
# ...

# %%
# !ls -1 /content/drive/MyDrive/YOLO/dataset/images/train | wc -l
# Out:
# 26266
